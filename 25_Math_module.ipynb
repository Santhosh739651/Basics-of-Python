# %%
#Mathmodule--built-in module that provides the mathematical functions
#Ex:-square root,power,factorial

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
#Constants in math module:--
#1.Euler's number->math.e constant returns Euler's number:2.718281828459045
import math
print(f"Euler's number:{math.e}")
# Out:
# Euler's number:2.718281828459045

# %%
#2.Pi value
print(f"Pi value:{math.pi}")

r=4
pie=math.pi
print(f"Area of Circle:{pie* r *r}")
# Out:
# Pi value:3.141592653589793
# Area of Circle:50.26548245743669

# %%
#3.tau--is ratio of the cicumference of the radius
print(f"Tau vale:{math.tau}")
# Out:
# Tau vale:6.283185307179586

# %%
#4.Infinity (inf)
import math
print(math.inf)
print(-math.inf)
print(math.inf>1000)
print(-math.inf<1)
# Out:
# inf
# -inf
# True
# True

# %%
#Numeric functions in Mathmodule
#1.finding the ceiling and the floor
import math
a=2.3
print(f"The ceil of 2.3 is {math.ceil (a)}")
print(f"The Floor of 2.3 is {math.floor(a)}")
# Out:
# The ceil of 2.3 is 3
# The Floor of 2.3 is 2

# %%
#2.Finding the factorial of the number
import math
n=int(input("Enter the number:"))
print(f"The factorial of 5 is : {math.factorial(n)}")
# Out:
# The factorial of 5 is : 24

# %%
#Finding the GCD
import math
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
print(f"GCD of numbers : {math.gcd(a,b)}")
# Out:
# GCD of numbers : 5

# %%
# 4.Finding the absolute value
import math
a=-10
print(f"The absolute value of -10 is : {math.fabs(a)}")
# Out:
# The absolute value of -10 is : 10.0

# %%
#Logarthmic and Power Functions
#1. Finding the power of exp(e)
import math
test_int=4
test_neg_int=-3
test_float=0.00
print(math.exp(test_int))
# Out:
# 54.598150033144236

# %%
#2.finding the power of a number
print(f"The value of 4 power is : {pow(3,4)}")
# Out:
# The value of 4 power is : 81

# %%
#3.Finding the logarithm
import math
print(f"The value of log 2 with base 3 is : {math.log(2,3)}")
print(f"The value of log2 of 16 is : {math.log(2,16)}")
# Out:
# The value of log 2 with base 3 is : 0.6309297535714574
# The value of log2 of 16 is : 0.25

# %%
#4.square root
import math
print(math.sqrt(2))
print(math.sqrt(4))
# Out:
# 1.4142135623730951
# 2.0

# %%
#Trigonometric and Angular functions
#1.Finding sine,cosine and tangent
import math
a=math.pi/6
print(f"The sin value : {math.sin(a)}")
print(f"The cos value: {math.cos(a)}")
print(f"The tan value: {math.tan(a)}")
# Out:
# The sin value : 0.49999999999999994
# The cos value: 0.8660254037844387
# The tan value: 0.5773502691896257

# %%
#2.Converting values from degrees to radians and vice versa
import math
a=math.pi/6
b=30
print(f"Degress: {math.degrees(a)}")
print(f"Radians : {math.radians(a)}")
# Out:
# Degress: 29.999999999999996
# Radians : 0.009138522593601256
