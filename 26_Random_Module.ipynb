# %%
#Random module generates the random niumbers
import random
a=[1,2,3,4,5]
print(random.choice(a))
# Out:
# 1

# %%
#generating the values in a range
import random
r=random.randint(2,100)
print(r)
r2=random.randint(-100,-10)
print(r2)
# Out:
# 57
# -81

# %%
from random import random
print(random())
# Out:
# 0.4684710781213306

# %%
import random
a=[10,23,4,7,345,5656,2,445,5,355,552]
print(random.choice(a))
# Out:
# 355

# %%
import random
a=(11,2,33,4,555)
print(random.choice(a))
# Out:
# 4

# %%
import random
s="SANTHOSH"
print(random.choice(s))
# Out:
# S

# %%
#Select multiple unique Random Items
from random import sample
a=[1,2,3,4,5]
print(sample(a,2))
# Out:
# [4, 1]

# %%
#Shuffling
a=[1,2,3,4,5,6,7]
print("Before Shuffling : ",a)
random.shuffle(a)
print("After Shuffling : ",a)
# Out:
# Before Shuffling :  [1, 2, 3, 4, 5, 6, 7]
# After Shuffling :  [3, 5, 6, 2, 4, 7, 1]
