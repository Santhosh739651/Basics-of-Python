# %%
#Float point to three-decimal using (:.2f)
amount=15.7458920
print("Amount:{:.3f}".format(amount))

# %%
# Seperating with comma
print('1','1','2026',sep=',')

#Printing date
print("Date: "'1','1','2026',sep='/')

#Seperating strings with custom operator
print('Santhosh','Python','Program',sep=' @ ')

# %%
#Formating strings and numbers in python
num = 5
result = num+5
print(result)

#Assinging multiple variables in a line
a = b = c =100
print("a:",a)
print("b:",b)
print("c:",c)

#Assinging multiple variables with different types of data
x,y,z=10,2.5,'Santhosh'
print("x:",x)
print("Float:",y)
print("Name:",z)

# %%
#Using f string for formatting
name = 'Santhosh'
age = 19
print(f"My name is {name} and age is {age}..")

#Printing table
n=int(input("Enter the number to print table:"))
for i in range(11):
    print(f"{n} X {i} = {n*i}")
